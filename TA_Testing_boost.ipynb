# %% [markdown]
# # Import Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import xgboost as xgb
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.svm import SVR
from sklearn.metrics import r2_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Data Understanding

# %%
df = pd.read_csv(r'DataProduksi.csv')
df
# Out:
#     Tanggal  Minyak Sawit  Karet Kering    Teh
# 0    Jan-09       1427.10         50.00   8.80
# 1    Feb-09       1188.00         45.50   7.90
# 2    Mar-09       1346.70         40.10   8.50
# 3    Apr-09       1193.50         38.80   9.30
# 4    May-09       1239.50         47.20  10.30
# ..      ...           ...           ...    ...
# 115  Aug-18       2075.95         35.32   5.99
# 116  Sep-18       2093.69         49.37   6.78
# 117  Oct-18       2075.70         51.21   8.12
# 118  Nov-18       1931.94         48.77   8.48
# 119  Dec-18       1785.71         52.39   8.25
#
# [120 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tanggal       120 non-null    object
#  1   Minyak Sawit  120 non-null    float64
#  2   Karet Kering  120 non-null    float64
#  3   Teh           120 non-null    float64
# dtypes: float64(3), object(1)
# memory usage: 3.9+ KB

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Change date format

# %%
df['Tanggal'] = pd.to_datetime(
    df['Tanggal'], format='%b-%y').dt.strftime('%Y-%m')
df.head()
# Out:
#    Tanggal  Minyak Sawit  Karet Kering   Teh
# 0  2009-01        1427.1          50.0   8.8
# 1  2009-02        1188.0          45.5   7.9
# 2  2009-03        1346.7          40.1   8.5
# 3  2009-04        1193.5          38.8   9.3
# 4  2009-05        1239.5          47.2  10.3

# %% [markdown]
# ## Separating DataFrame Columns into Separate Variables

# %%
dates = df['Tanggal'].values
minyak_sawit = df['Minyak Sawit'].values
karet_kering = df['Karet Kering'].values
teh = df['Teh'].values

# %% [markdown]
# ## Windowed Dataset

# %%
def windowed_dataset(data, window_size):
    X = []
    y = []
    for i in range(len(data) - window_size):
        X.append(data[i:i + window_size])
        y.append(data[i + window_size])
    return np.array(X), np.array(y)

# %% [markdown]
# ## Split Dataset

# %%
def split_data(X, y, split_percentage):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=split_percentage, shuffle=False)
    return X_train, X_test, y_train, y_test

# %% [markdown]
# ## Normalization

# %%
scaler = MinMaxScaler()
def normalization(data):
    return scaler.fit_transform(data.reshape(-1, 1))


def to_original_value(data):
    return scaler.inverse_transform(data.reshape(-1, 1))

# %% [markdown]
# # Generate Output

# %% [markdown]
# ## Generate R2 Score

# %%
def generate_r2(y_test, y_pred):
    r2 = r2_score(y_test,y_pred)
    print("R2 score: {:.2%}".format(r2))

# %% [markdown]
# ## Generate Plot

# %%
def generate_plot(X_data, y_data, X_name, y_name, attribute_name):
    plt.figure(figsize=(10, 6))
    plt.plot(X_data, label=X_name)
    plt.plot(y_data, label=y_name)
    plt.title(f'{X_name} vs {y_name} {attribute_name}')
    plt.xlabel('Bulan')
    plt.ylabel('Nilai Produksi')
    plt.legend()
    plt.show()
    print('\n')

# %%
def generate_plot_lstm(X_data, y_data, X_name, y_name, attribute_name, start_idx=None):
    plt.figure(figsize=(10, 6))
    plt.plot(X_data, label=X_name)
    if start_idx is not None:
        plt.plot(range(start_idx, start_idx + len(y_data)), y_data, label=y_name)
    else:
        plt.plot(y_data, label=y_name)
    plt.title(f'{X_name} vs {y_name} {attribute_name}')
    plt.xlabel('Bulan')
    plt.ylabel('Nilai Produksi')
    plt.legend()
    plt.show()
    print('\n')

# %% [markdown]
# ## Generate Prediction

# %% [markdown]
# ### LSTM Predict Future

# %%
def predict_future_lstm(model, data, window_size, num_months):
    data_norm = normalization(data)
    last_window = data_norm[-window_size:]
    future_predictions = []
    for i in range(num_months):
        next_prediction = model.predict(last_window.reshape(1, window_size, 1))
        future_predictions.append(next_prediction[0][0])
        last_window = np.append(last_window[1:], next_prediction)[np.newaxis, :]
    return np.array(future_predictions)

# %% [markdown]
# ### SVR Predict Future

# %%
def predict_future_svr(model, data, num_features, num_months):
    data_norm = normalization(data)
    input_seq = data_norm[-num_features:]
    future_preds_norm = []
    for i in range(num_months):
        pred_norm = model.predict(input_seq.reshape(1, -1))
        future_preds_norm.append(pred_norm[0])
        input_seq = np.append(input_seq[1:], pred_norm)
    return to_original_value(np.array(future_preds_norm))

# %% [markdown]
# # LSTM

# %% [markdown]
# ## LSTM Model

# %%
# def model_lstm(data, attribute_name, split_percentage=0.8, epochs=50, activation='relu', window_size=12, lstm_size=[60,60,60], dense_size=[30,10]):
#     X, y = windowed_dataset(normalization(data), window_size=window_size)
#     X_train, X_test, y_train, y_test = split_data(X, y, split_percentage)

#     model = Sequential()
#     for idx, size in enumerate(lstm_size):
#         if idx == 0:
#             model.add(LSTM(size, return_sequences=True, activation=activation, input_shape=(window_size, 1)))
#         elif idx == len(lstm_size) - 1:
#             model.add(LSTM(size, activation=activation))
#         else:
#             model.add(LSTM(size, return_sequences=True, activation=activation))
#         # model.add(Dropout(0.2))
    
#     for size in dense_size:
#         model.add(Dense(size, activation=activation))
#     model.add(Dense(1))

#     model.compile(loss="mae", optimizer=Adam(), metrics=["mae"])
#     model.fit(X_train, y_train, epochs=epochs, verbose=0)

#     y_pred = model.predict(X_test)
#     train_pred = model.predict(X)
#     train_pred_to_plot = np.empty_like(data)
#     train_pred_to_plot[:window_size] = np.nan
#     train_pred_to_plot[window_size:] = to_original_value(train_pred).flatten()

#     generate_r2(y_test, y_pred)

#     generate_plot(to_original_value(y_test), to_original_value(y_pred), 'Data Test', 'Data Prediksi', attribute_name)
#     generate_plot(data, train_pred_to_plot, 'Data Training','Data Prediksi', attribute_name)


#     num_months = [2, 5, 7, 8]
#     for n in num_months:
#         future_preds = predict_future_lstm(model, minyak_sawit, 1, n)
#         print(f"Prediksi {n} bulan ke depan: {future_preds}")

# %%
def model_lstm_xgb(data, attribute_name, split_percentage=0.8, epochs=50, activation='relu', window_size=12, lstm_size=[60,60,60], dense_size=[30,10], xgb_params=None):
    X, y = windowed_dataset(normalization(data), window_size=window_size)
    X_train, X_test, y_train, y_test = split_data(X, y, split_percentage)

    model = Sequential()
    for idx, size in enumerate(lstm_size):
        if idx == 0:
            model.add(LSTM(size, return_sequences=True, activation=activation, input_shape=(window_size, 1)))
        elif idx == len(lstm_size) - 1:
            model.add(LSTM(size, activation=activation))
        else:
            model.add(LSTM(size, return_sequences=True, activation=activation))
        # model.add(Dropout(0.2))
    
    for size in dense_size:
        model.add(Dense(size, activation=activation))
    model.add(Dense(1))

    model.compile(loss="mae", optimizer=Adam(), metrics=["mae"])
    model.fit(X_train, y_train, epochs=epochs, verbose=0)

    y_pred = model.predict(X_test)
    train_pred = model.predict(X)
    train_pred_to_plot = np.empty_like(data)
    train_pred_to_plot[:window_size] = np.nan
    train_pred_to_plot[window_size:] = to_original_value(train_pred).flatten()

    generate_r2(y_test, y_pred)

    generate_plot(to_original_value(y_test), to_original_value(y_pred), 'Data Test', 'Data Prediksi', attribute_name)
    generate_plot(data, train_pred_to_plot, 'Data Training','Data Prediksi', attribute_name)
    
    if xgb_params is None:
        xgb_params = {
            'max_depth': 5,
            'learning_rate': 0.1,
            'n_estimators': 100,
            'objective': 'reg:squarederror'
        }

    X_train_lstm = model.predict(X_train)
    X_test_lstm = model.predict(X_test)
    X_lstm = model.predict(X)

    xgb_model = xgb.XGBRegressor(**xgb_params)
    xgb_model.fit(X_train_lstm, y_train)

    y_pred_xgb = xgb_model.predict(X_test_lstm)
    train_pred_xgb = xgb_model.predict(X_lstm)
    train_pred_xgb_to_plot = np.empty_like(data)
    train_pred_xgb_to_plot[:window_size] = np.nan
    train_pred_xgb_to_plot[window_size:] = to_original_value(train_pred_xgb).flatten()

    generate_r2(y_test, y_pred_xgb)

    generate_plot(to_original_value(y_test), to_original_value(y_pred_xgb), 'Data Test', 'Data Prediksi (XGBoost)', attribute_name)
    generate_plot(data, train_pred_xgb_to_plot, 'Data Training','Data Prediksi (XGBoost)', attribute_name)

    num_months = [2, 5, 7, 8]
    for n in num_months:
        future_preds = predict_future_lstm(model, minyak_sawit, 1, n)
        print(f"Prediksi {n} bulan ke depan: {future_preds}")

# %% [markdown]
# ## LSTM Evaluation

# %% [markdown]
# ### Minyak Sawit

# %%
model_lstm(minyak_sawit, 'Minyak Sawit', 0.8, 200, 'relu', 2)
# Out:
# 3/3 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 3ms/step
# R2 score: 43.68%
# 1/1 [==============================] - 0s 303ms/step
# 1/1 [==============================] - 0s 24ms/step
# Prediksi 2 bulan ke depan: [0.19131656 0.13523227]
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 48ms/step
# Prediksi 5 bulan ke depan: [0.19131656 0.13523227 0.13062003 0.13022274 0.13018858]
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 16ms/step
# Prediksi 7 bulan ke depan: [0.19131656 0.13523227 0.13062003 0.13022274 0.13018858 0.13018565
#  0.13018541]
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# Prediksi 8 bulan ke depan: [0.19131656 0.13523227 0.13062003 0.13022274 0.13018858 0.13018565
#  0.13018541 0.13018538]

# %% [markdown]
# ### Karet Kering

# %%
model_lstm(karet_kering, 'Karet Kering', 0.8, 110, 'relu', 12)
# Out:
# 3/3 [==============================] - 1s 8ms/step
# 4/4 [==============================] - 0s 3ms/step
# R2 score: -6.29%
# 1/1 [==============================] - 0s 365ms/step
# 1/1 [==============================] - 0s 25ms/step
# Prediksi 2 bulan ke depan: [0.13290264 0.1319415 ]
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 32ms/step
# Prediksi 5 bulan ke depan: [0.13290264 0.1319415  0.13193986 0.13193984 0.13193984]
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 24ms/step
# Prediksi 7 bulan ke depan: [0.13290264 0.1319415  0.13193986 0.13193984 0.13193984 0.13193984
#  0.13193984]
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# Prediksi 8 bulan ke depan: [0.13290264 0.1319415  0.13193986 0.13193984 0.13193984 0.13193984
#  0.13193984 0.13193984]

# %% [markdown]
# ### Teh

# %%
model_lstm(teh, 'Teh', 0.8, 100, 'relu', 12)
# Out:
# 3/3 [==============================] - 0s 8ms/step
# 4/4 [==============================] - 0s 5ms/step
# R2 score: 2.04%
# 1/1 [==============================] - 0s 291ms/step
# 1/1 [==============================] - 0s 16ms/step
# Prediksi 2 bulan ke depan: [0.10995061 0.10871839]
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 16ms/step
# Prediksi 5 bulan ke depan: [0.10995061 0.10871839 0.10871603 0.10871602 0.10871602]
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# Prediksi 7 bulan ke depan: [0.10995061 0.10871839 0.10871603 0.10871602 0.10871602 0.10871602
#  0.10871602]
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# Prediksi 8 bulan ke depan: [0.10995061 0.10871839 0.10871603 0.10871602 0.10871602 0.10871602
#  0.10871602 0.10871602]

# %% [markdown]
# # SVR (Support Vector Regression)

# %% [markdown]
# ## SVR Model

# %%
def model_svr(data, attribute_name, split_percentage=0.8, c=1000, gamma='scale', epsilon=0.1):
    X_train, X_test, y_train, y_test = split_data(normalization(data), normalization(data), split_percentage)


    model = SVR(kernel='rbf', C=c, gamma=gamma, epsilon=epsilon)
    model.fit(X_train.reshape(-1,1), y_train.ravel())
    

    y_pred = model.predict(X_test)
    train_pred = model.predict(X_train.reshape(-1,1))

    generate_r2(y_test, y_pred)

    generate_plot(to_original_value(y_test), to_original_value(y_pred), 'Data Test', 'Data Prediksi', attribute_name)
    generate_plot(to_original_value(X_train), to_original_value(train_pred), 'Data Training','Data Prediksi', attribute_name)

    num_months = [2, 5, 7, 8]
    for n in num_months:
        future_preds = predict_future_svr(model, minyak_sawit, 1, n)
        print(f"Prediksi {n} bulan ke depan: {future_preds}")

# %% [markdown]
# ## SVR Evaluation

# %% [markdown]
# ### Minyak Sawit

# %%
model_svr(minyak_sawit, 'Minyak Sawit', 0.7, 100, .01, .01)
# Out:
# R2 score: 99.25%
# Prediksi 2 bulan ke depan: [[1763.52528998]
#  [1742.27765478]]
# Prediksi 5 bulan ke depan: [[1763.52528998]
#  [1742.27765478]
#  [1721.91867008]
#  [1702.40336354]
#  [1683.68987585]]
# Prediksi 7 bulan ke depan: [[1763.52528998]
#  [1742.27765478]
#  [1721.91867008]
#  [1702.40336354]
#  [1683.68987585]
#  [1665.73916339]
#  [1648.51473641]]
# Prediksi 8 bulan ke depan: [[1763.52528998]
#  [1742.27765478]
#  [1721.91867008]
#  [1702.40336354]
#  [1683.68987585]
#  [1665.73916339]
#  [1648.51473641]
#  [1631.98242794]]

# %% [markdown]
# ### Karet Kering

# %%
model_svr(karet_kering, 'Karet Kering', 0.7, 100, .1, .01)
# Out:
# R2 score: 99.47%
# Prediksi 2 bulan ke depan: [[1752.56384886]
#  [1722.45061675]]
# Prediksi 5 bulan ke depan: [[1752.56384886]
#  [1722.45061675]
#  [1694.94110287]
#  [1669.69165053]
#  [1646.42292637]]
# Prediksi 7 bulan ke depan: [[1752.56384886]
#  [1722.45061675]
#  [1694.94110287]
#  [1669.69165053]
#  [1646.42292637]
#  [1624.90483634]
#  [1604.94557756]]
# Prediksi 8 bulan ke depan: [[1752.56384886]
#  [1722.45061675]
#  [1694.94110287]
#  [1669.69165053]
#  [1646.42292637]
#  [1624.90483634]
#  [1604.94557756]
#  [1586.38354468]]

# %% [markdown]
# ### Teh

# %%
model_svr(teh, 'Teh', 0.8, 100, .1, .01)
# Out:
# R2 score: 99.49%
# Prediksi 2 bulan ke depan: [[1784.56406286]
#  [1783.44099079]]
# Prediksi 5 bulan ke depan: [[1784.56406286]
#  [1783.44099079]
#  [1782.34030179]
#  [1781.26152553]
#  [1780.20420292]]
# Prediksi 7 bulan ke depan: [[1784.56406286]
#  [1783.44099079]
#  [1782.34030179]
#  [1781.26152553]
#  [1780.20420292]
#  [1779.16788581]
#  [1778.15213663]]
# Prediksi 8 bulan ke depan: [[1784.56406286]
#  [1783.44099079]
#  [1782.34030179]
#  [1781.26152553]
#  [1780.20420292]
#  [1779.16788581]
#  [1778.15213663]
#  [1777.15652809]]
